# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

sns.set()

# %matplotlib inline

# %%
pd.set_option("display.max_columns", None)

# %%
df = pd.read_csv('PfizerTurnoverPredictionModel.csv')
# Out:
# /Users/atsukosakurai/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (7,13,24,25,26,27,28,29,30) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
#df.iloc[:, [7,13,24,25,26,27,28,29,30]].head()

# %%
df.shape
# Out:
# (4723161, 59)

# %%
df_ran_sam = df.sample(n=100000, random_state=1)

# %%
fig, ax = plt.subplots(figsize=(13,8))       
sns.heatmap(df_ran_sam.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Status'].value_counts()
# Out:
# 0    4718533
# 1       4628
# Name: Status, dtype: int64

# %% [markdown]
# # How many unique departments are there in the dataset?

# %%
df['DEPARTMENT'].nunique()
# Out:
# 3446

# %%
df['DEPTCD'].nunique()
# Out:
# 10383

# %% [markdown]
# # **Explore the COMPARATIO Column:**

# %%
compr_min = df['COMPARATIO'].min()
compr_max = df['COMPARATIO'].max()
print('Range of COMPARATIO is:', compr_min, 'to', compr_max)
# Out:
# Range of COMPARATIO is: 0.0 to 3666.07915384615

# %%
compr_mean = df['COMPARATIO'].mean()
print('Mean of COMPRATIO is:', compr_mean)
# Out:
# Mean of COMPRATIO is: 0.984369436666505

# %%
df.isnull().sum()
# Out:
# POS_LEVEL1                                            0
# POS_LEVEL2                                         4001
# POS_LEVEL3                                         4743
# POS_LEVEL4                                        12524
# POS_LEVEL5                                        54023
# POSITIONLVL                                        5935
# DEPARTMENT                                         1633
# DEPTCD                                               25
# RPTG_DIV_MAPPING                                      0
# REGION                                                0
# COUNTRY                                               0
# LOCATION                                              0
# JOB_FUNCTION                                          0
# JOBSUBFUNCTION                                    96378
# LGTHOFSVC                                         12504
# TIMEINJOB                                          5577
# TIMEINPOSITION                                     7274
# COMPARATIO                                      1070434
# GLBLDEPTLVL03                                      8500
# GLBLDEPTLVL04                                     90816
# GLBLDEPTLVL05                                    325606
# GLBLDEPTLVL06                                   1030759
# Month_Year                                            0
# CALYRMO                                         4718533
# CATEGORY                                        4718533
# VOL_INVOL                                       4718533
# ACTIONDT                                        4718533
# ACTION                                          4718574
# ACTIONCD                                        4718533
# REASON                                          4718533
# RSNCD                                           4718533
# Status                                                0
# Country Level Manufacturing                     1976866
# Country Level Sales                             1976866
# Country Level R&D                               1976866
# Country Level Finance                           1976866
# Country Level Legal                             1976866
# Country Level HR                                1976866
# Country Level IT                                1976866
# Country Level Pharma Other                      1976866
# Country Level Cost of Living Index              1450443
# Country Level Traffic Index                     1498527
# Country Level Time Index (in minutes)           1498527
# Country Level Time Ex Index                     1498527
# Country Level Inefficiencies Index              1498527
# Country Level Unemployment Rate (%)             1460059
# Country Level Corruption Perception Index       1443887
# Country Level Inflation (%)                     1443673
# Country Level GDP (nominal) (in USD billion)    1443673
# Country Level Pharma Industry Growth            4279764
# Country Level Labor Market Risk Index Score     2537391
# Country Level Political Risk Index Score        2537391
# Country Level Power distance                    2548772
# Country Level Individualism                     2548772
# Country Level Masculinity                       2548772
# Country Level Uncertainty avoidance             2549830
# Country Level Long term orientation             2577184
# Country Level Indulgence                        2598103
# RandomID                                              0
# dtype: int64

# %% [markdown]
# ## Summary Stats for Comparatio Column

# %%
df_comparatio_summ_stats = df.groupby('JOB_FUNCTION')['COMPARATIO'].agg(['count', 'min', 'max', 'mean', 'median', 'std', 'sum'])
df_comparatio_summ_stats['range'] = df_comparatio_summ_stats['max'] - df_comparatio_summ_stats['min']
df_comparatio_summ_stats
# Out:
#                                   count       min          max      mean  \
# JOB_FUNCTION
# Admin & Support Services          21469  0.005910    11.735050  1.051239
# Administrative                    39668  0.000000     2.683647  1.019946
# Aviation and Transportation        2084  0.768455     1.252862  1.063859
# Bus Dev & Strategic Planning      22925  0.000000  1177.667737  1.057479
# Continuous Imprv and Proj Mgmt    36305  0.000000    11.496000  0.979405
# Engineering                      142886  0.000000    12.843530  1.004513
# Environmental, Health & Safety    14427  0.000000     1.934524  1.016030
# Executive                           169  0.745200     1.186047  1.013709
# Executive Leadership/Managemen      743  0.853988     1.221182  1.021140
# Finance & Accounting             146561  0.000000   935.480794  0.982074
# Flight Operations                   468  0.802469     1.259394  1.036482
# Generic                              27  0.000000     1.500180  0.833691
# Global Operations                 19055  0.000000    35.331888  1.031435
# Global Procurement                35863  0.000000     2.319891  0.990503
# Human Resources                   40298  0.000000    16.303232  1.000081
# Information & Business Tech      125025  0.000000  3666.079154  1.048352
# Legal Affairs                     30132  0.000000     3.696695  1.030603
# Logistics & Supply Chain Mgmt    121428  0.000000    55.126848  0.976291
# Manufacturing                    323513  0.000000    15.179525  0.975512
# Market Access                     35326  0.000000     2.802568  0.986908
# Marketing and Market Research    144584  0.000000   142.662531  0.986829
# Medical                          346638  0.000000    39.412564  0.964141
# Mkt & Sales/Commercial Bus        45373  0.000000   478.486047  1.029915
# Non-Sales                           132  0.519856     1.362188  0.921776
# Public Affairs & Communication    26705  0.000000    12.009075  1.004584
# Quality Assurance and Control    283809  0.000000    12.518221  0.947778
# Regulatory Affairs               100124  0.000000    54.518783  0.951641
# Research and Development         229057  0.000000    34.367554  1.011693
# Sales                           1262220  0.000000    17.189488  0.981140
# Sales Operations & Admin          23435  0.000000     2.627751  0.993983
# Sales Training                    11019  0.303876     4.308202  1.025400
# Support Services                  21259  0.000000    10.298245  0.980360
#
#                                   median        std           sum        range
# JOB_FUNCTION
# Admin & Support Services        1.054337   0.266862  2.256905e+04    11.729140
# Administrative                  1.012785   0.188981  4.045920e+04     2.683647
# Aviation and Transportation     1.048138   0.101188  2.217083e+03     0.484407
# Bus Dev & Strategic Planning    1.006769   7.772662  2.424272e+04  1177.667737
# Continuous Imprv and Proj Mgmt  0.974033   0.137016  3.555730e+04    11.496000
# Engineering                     1.000003   0.158537  1.435308e+05    12.843530
# Environmental, Health & Safety  1.023318   0.141392  1.465826e+04     1.934524
# Executive                       1.042801   0.097108  1.713168e+02     0.440847
# Executive Leadership/Managemen  1.015590   0.095327  7.587070e+02     0.367195
# Finance & Accounting            0.966038   2.477271  1.439338e+05   935.480794
# Flight Operations               1.044418   0.124348  4.850737e+02     0.456925
# Generic                         1.190371   0.608137  2.250965e+01     1.500180
# Global Operations               1.022294   0.296108  1.965399e+04    35.331888
# Global Procurement              0.990522   0.159432  3.552239e+04     2.319891
# Human Resources                 1.000747   0.175309  4.030126e+04    16.303232
# Information & Business Tech     1.023438  10.366218  1.310702e+05  3666.079154
# Legal Affairs                   1.040639   0.146607  3.105414e+04     3.696695
# Logistics & Supply Chain Mgmt   0.965795   0.258132  1.185491e+05    55.126848
# Manufacturing                   0.961348   0.198870  3.155908e+05    15.179525
# Market Access                   0.980952   0.144768  3.486352e+04     2.802568
# Marketing and Market Research   0.986833   0.411588  1.426797e+05   142.662531
# Medical                         0.962636   0.162047  3.342080e+05    39.412564
# Mkt & Sales/Commercial Bus      1.001582   2.404492  4.673035e+04   478.486047
# Non-Sales                       0.901648   0.148973  1.216744e+02     0.842332
# Public Affairs & Communication  1.000000   0.164552  2.682741e+04    12.009075
# Quality Assurance and Control   0.941873   0.155500  2.689879e+05    12.518221
# Regulatory Affairs              0.942434   0.228572  9.528208e+04    54.518783
# Research and Development        1.007540   0.120491  2.317353e+05    34.367554
# Sales                           0.977182   0.201139  1.238415e+06    17.189488
# Sales Operations & Admin        0.994209   0.169652  2.329400e+04     2.627751
# Sales Training                  1.034661   0.168686  1.129888e+04     4.004326
# Support Services                0.983446   0.163993  2.084147e+04    10.298245

# %% [markdown]
# ## Comparatio Quantiles

# %%
df['COMPARATIO'].quantile([.1, .25, .5, .75])
# Out:
# 0.10    0.800000
# 0.25    0.881781
# 0.50    0.979569
# 0.75    1.072114
# Name: COMPARATIO, dtype: float64

# %%
df.boxplot(column=['COMPARATIO'], figsize=(13, 8))
# Out:
# <AxesSubplot:>

# %%
#comparatio_outliers = df['COMPARATIO']> 10
#len(df[comparatio_outliers])

# %%
comparatio_dict = {'greater than this value': [3, 4, 7, 10], 'number of data points': [794, 212, 203, 172]}
pd.DataFrame.from_dict(comparatio_dict)
# Out:
#    greater than this value  number of data points
# 0                        3                    794
# 1                        4                    212
# 2                        7                    203
# 3                       10                    172

# %%
# isolate the data where someone left the company
cond = df['Status'] == 1

# %%
left_company = df[cond]

# %%
left_company.shape
# Out:
# (4628, 59)

# %%
left_company['DEPARTMENT'].nunique()
# Out:
# 598

# %%
top_depts = left_company.groupby('DEPARTMENT')['Status'].count().sort_values(ascending=False)
top_depts.head(10)
# Out:
# DEPARTMENT
# EM - China                        288
# PEH CN Acute Disease Biz Group    209
# PBG China ONC&RD Sales            117
# Kalamazoo Michigan                113
# Vizag Manufacturing               112
# Sterile Injectable Ops DOM        103
# PEH - APAC                         99
# PGS - Pharma Mfg Ops               98
# WSR-Safety, EP & Generics Reg      95
# QO Specialty/Biotech               93
# Name: Status, dtype: int64

# %%
top_30 = top_depts.head(30)
top_30.plot(kind='bar', title='Top 30 Turnovers By Department', ylabel='Sum of People Who Left',
         xlabel='Department', figsize=(13, 8))
# Out:
# <AxesSubplot:title={'center':'Top 30 Turnovers By Department'}, xlabel='Department', ylabel='Sum of People Who Left'>

# %% [markdown]
# # Explore Job Function

# %%
df['JOB_FUNCTION'].nunique()
# Out:
# 32

# %%
df['JOB_FUNCTION'].unique()
# Out:
# array(['Global Operations', 'Engineering',
#        'Logistics & Supply Chain Mgmt', 'Marketing and Market Research',
#        'Finance & Accounting', 'Regulatory Affairs',
#        'Quality Assurance and Control', 'Legal Affairs',
#        'Information & Business Tech', 'Human Resources',
#        'Global Procurement', 'Sales', 'Continuous Imprv and Proj Mgmt',
#        'Admin & Support Services', 'Research and Development',
#        'Manufacturing', 'Medical', 'Bus Dev & Strategic Planning',
#        'Public Affairs & Communication', 'Flight Operations',
#        'Environmental, Health & Safety', 'Mkt & Sales/Commercial Bus',
#        'Market Access', 'Executive', 'Non-Sales', 'Generic',
#        'Sales Operations & Admin', 'Administrative', 'Support Services',
#        'Sales Training', 'Aviation and Transportation',
#        'Executive Leadership/Managemen'], dtype=object)

# %%
dfg_jf = df.groupby('JOB_FUNCTION')['Status'].sum()
dfg_jf
# Out:
# JOB_FUNCTION
# Admin & Support Services             0
# Administrative                      47
# Aviation and Transportation          0
# Bus Dev & Strategic Planning        16
# Continuous Imprv and Proj Mgmt      38
# Engineering                        195
# Environmental, Health & Safety      19
# Executive                            0
# Executive Leadership/Managemen       0
# Finance & Accounting               168
# Flight Operations                    0
# Generic                              0
# Global Operations                    5
# Global Procurement                  27
# Human Resources                     25
# Information & Business Tech         53
# Legal Affairs                       22
# Logistics & Supply Chain Mgmt      110
# Manufacturing                      646
# Market Access                       53
# Marketing and Market Research      170
# Medical                            428
# Mkt & Sales/Commercial Bus          35
# Non-Sales                            0
# Public Affairs & Communication      29
# Quality Assurance and Control      353
# Regulatory Affairs                 112
# Research and Development           232
# Sales                             1800
# Sales Operations & Admin            17
# Sales Training                       3
# Support Services                    25
# Name: Status, dtype: int64

# %%
dfg_jf.plot(kind='bar', title='Turnover by Job function', ylabel='Sum of People Who Left',
         xlabel='Job Function', figsize=(13, 8))
# Out:
# <AxesSubplot:title={'center':'Turnover by Job function'}, xlabel='Job Function', ylabel='Sum of People Who Left'>
